# %% [markdown]
# #  실습:SVHN 데이터를 이용한 분류모델
# - SVHN 데이터셋에 대하여 조사하고, 실습합니다.
#
# - 형식: RGB(3채널)
# - 크기: 32×32
# - 분류: 0~9 (도로 간판 숫자 이미지)
# - 장점: CIFAR10처럼 3채널 컬러 이미지 + 숫자라 학습 안정적
# - 단점: 라벨이 약간 불균형할 수 있음

# %% [markdown]
# ### [1] GPU/CPU 장치 할당

# %%
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### [2] 데이터셋 다운로드 및 기본정보
#
#           train_dataset = datasets.CIFAR10(
#               root="./data",
#               train=True, # SVHN에서는  split='train' 으로 해야함.
#               download=True,
#               transform=transform
#           )
# -  split='train', # SVHN의 표준 훈련 분할, 기존작업과 다름
# -  split='test', # SVHN의 표준 훈련 분할, 기존작업과 다름

# %% [markdown]
# ##
